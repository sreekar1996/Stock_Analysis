# %%
import pandas as pd

# %%
data=pd.read_csv("data.csv")

# %%
data
# Out:
#          Date    Symbol Series      Open      High       Low      LTP  \
# 0         NaN       NaN    NaN       NaN       NaN       NaN      NaN
# 1   08-Apr-19  RELIANCE     EQ  1,356.00  1,357.50  1,323.70  1328.00
# 2   05-Apr-19  RELIANCE     EQ  1,360.95  1,363.90  1,343.00  1355.85
# 3   04-Apr-19  RELIANCE     EQ  1,379.00  1,383.70  1,347.25  1354.50
# 4   03-Apr-19  RELIANCE     EQ  1,392.75  1,403.00  1,372.00  1374.60
# 5   02-Apr-19  RELIANCE     EQ  1,398.00  1,403.10  1,380.10  1388.20
# 6   01-Apr-19  RELIANCE     EQ  1,370.00  1,406.80  1,362.55  1391.60
# 7   29-Mar-19  RELIANCE     EQ  1,370.05  1,376.85  1,355.10  1363.05
# 8   28-Mar-19  RELIANCE     EQ  1,350.25  1,369.80  1,342.80  1362.00
# 9   27-Mar-19  RELIANCE     EQ  1,377.95  1,377.95  1,344.25  1347.00
# 10  26-Mar-19  RELIANCE     EQ  1,330.30  1,371.60  1,330.00  1369.00
# 11  25-Mar-19  RELIANCE     EQ  1,330.60  1,336.85  1,316.70  1328.00
# ...

# %%
data=data.drop(labels=0,axis=0)

# %%
data=data.iloc[0:62,0:10]

# %%
data.head()
# Out:
#         Date    Symbol Series      Open      High       Low      LTP  \
# 1  08-Apr-19  RELIANCE     EQ  1,356.00  1,357.50  1,323.70  1328.00
# 2  05-Apr-19  RELIANCE     EQ  1,360.95  1,363.90  1,343.00  1355.85
# 3  04-Apr-19  RELIANCE     EQ  1,379.00  1,383.70  1,347.25  1354.50
# 4  03-Apr-19  RELIANCE     EQ  1,392.75  1,403.00  1,372.00  1374.60
# 5  02-Apr-19  RELIANCE     EQ  1,398.00  1,403.10  1,380.10  1388.20
#
#       Close     Volume     Turnover
# 1  1,329.25  87,23,577  1,16,467.35
# 2  1,353.90  67,28,239    91,000.90
# 3  1,353.05  83,75,674  1,13,962.56
# 4  1,375.20  78,49,461  1,09,122.96
# 5  1,389.70  80,12,636  1,11,403.74

# %%
import matplotlib.pyplot as plt
from matplotlib import pyplot
# %matplotlib inline
plt.figure(figsize=(28,18))
plt.plot(data.Date, data.Open)
plt.plot(data.Date, data.High)
plt.plot(data.Date, data.Low)
#plt.plot(data.Date, data.LTP)
plt.legend(loc='best')
pyplot.show()
#plt.figure(figsize=(16,8))

# %%
data["Open"].max()
# Out:
# '1,398.00'

# %%
data["Open"].min()
# Out:
# '1,095.00'

# %%
re=pd.read_csv("reliance.csv")

# %%
re.shape
# Out:
# (498, 15)

# %%
re.head()
# Out:
#      Symbol Series         Date  Prev Close  Open Price  High Price  \
# 0  RELIANCE     EQ  10-Apr-2017     1406.60     1410.00     1424.90
# 1  RELIANCE     EQ  11-Apr-2017     1381.35     1387.85     1400.45
# 2  RELIANCE     EQ  12-Apr-2017     1372.35     1382.80     1386.45
# 3  RELIANCE     EQ  13-Apr-2017     1354.00     1354.00     1373.40
# 4  RELIANCE     EQ  17-Apr-2017     1364.80     1365.00     1395.55
#
#    Low Price  Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0    1377.30     1384.75      1381.35        1396.97                7033141
# 1    1370.10     1375.70      1372.35        1382.90                7371727
# 2    1351.15     1355.00      1354.00        1363.72                6274215
# 3    1347.35     1365.80      1364.80        1365.73                2906188
# 4    1365.00     1391.45      1391.85        1380.35                2705854
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# ...

# %%
re.columns=['Symbol', 'Series', 'Date', 'Prev_Close', 'Open_Price', 'High_Price',
       'Low_Price', 'Last_Price', 'Close_Price', 'Average_Price',
       'Total_Traded_Quantity', 'Turnover', 'No_of_Trades', 'Deliverable_Qty',
       '%_Dly_Qt_to_Traded_Qty']

# %%
import matplotlib.pyplot as plt
from matplotlib import pyplot
# %matplotlib inline
plt.figure(figsize=(28,18))
plt.plot(re.Date, re.Open_Price)
#plt.plot(data.Date, data.LTP)
plt.legend(loc='best')
pyplot.show()
